# %% [markdown]
# # NLP Sentiment Analysis (PT-BR)
# Notebook simples de análise de sentimento.

# %%
sentences = [
    "Eu gostei muito deste produto",
    "Esse serviço foi horrível",
    "Achei razoável, poderia ser melhor"
]

for s in sentences:
    print(s)
